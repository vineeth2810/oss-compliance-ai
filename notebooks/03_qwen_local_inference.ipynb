# %%
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM

print("Torch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
# Out:
# Torch version: 2.12.0+cu130
# CUDA available: True

# %%
model_name = "Qwen/Qwen2.5-1.5B-Instruct"

tokenizer = AutoTokenizer.from_pretrained(model_name)

model = AutoModelForCausalLM.from_pretrained(
    model_name,
    torch_dtype="auto",
    device_map="auto"
)

print("Model loaded successfully.")
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/660 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/3.09G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/338 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/242 [00:00<?, ?B/s]
# Model loaded successfully.

# %%
prompt = """
You are an open-source license compliance assistant.

Classify the compliance risk for the scenario below.

License: GPL-3.0
License Family: Strong Copyleft
Project Type: commercial closed-source software
Distribution Model: distributed
Usage: core library

Return ONLY in this format:
Risk: Low/Medium/High
Reason: one short sentence
"""

messages = [
    {"role": "user", "content": prompt}
]

text = tokenizer.apply_chat_template(
    messages,
    tokenize=False,
    add_generation_prompt=True
)

inputs = tokenizer([text], return_tensors="pt").to(model.device)

outputs = model.generate(
    **inputs,
    max_new_tokens=200
)

response = tokenizer.decode(outputs[0], skip_special_tokens=True)

print(response)
# Out:
# system
# You are Qwen, created by Alibaba Cloud. You are a helpful assistant.
# user
#
# You are an open-source license compliance assistant.
#
# Classify the compliance risk for the scenario below.
#
# License: GPL-3.0
# License Family: Strong Copyleft
# Project Type: commercial closed-source software
# Distribution Model: distributed
# Usage: core library
#
# Return ONLY in this format:
# Risk: Low/Medium/High
# Reason: one short sentence
#
# assistant
# Risk: High
# Reason: The project is using a strong copyleft license (GPL-3.0) and distributing its core library commercially, which may restrict users from redistributing or modifying the software as required under the GPL terms. This could lead to legal issues if users attempt to circumvent these restrictions.
