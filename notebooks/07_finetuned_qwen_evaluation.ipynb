# %%
import os
import re
import pandas as pd
import torch

from datasets import load_dataset

from transformers import (
    AutoTokenizer,
    AutoModelForCausalLM
)

from peft import PeftModel

from sklearn.metrics import (
    accuracy_score,
    classification_report,
    confusion_matrix
)

# %%
df = pd.read_csv("../data/slm_eval_dataset.csv")

print("Dataset shape:", df.shape)

df.head()
# Out:
# Dataset shape: (20, 2)
#                                                input expected_risk
# 0  License: MIT License Family: Permissive Projec...           Low
# 1  License: MIT License Family: Permissive Projec...           Low
# 2  License: Apache-2.0 License Family: Permissive...           Low
# 3  License: BSD-3-Clause License Family: Permissi...           Low
# 4  License: LGPL-2.1 License Family: Weak Copylef...        Medium

# %%
base_model_name = "Qwen/Qwen2.5-1.5B-Instruct"

tokenizer = AutoTokenizer.from_pretrained(base_model_name)

base_model = AutoModelForCausalLM.from_pretrained(
    base_model_name,
    device_map="auto",
    torch_dtype=torch.float16
)

model = PeftModel.from_pretrained(
    base_model,
    "../models/qwen_oss_compliance_lora"
)

print("Fine-tuned Qwen loaded successfully.")
# Out:
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/338 [00:00<?, ?it/s]
# Fine-tuned Qwen loaded successfully.

# %%
def build_prompt(scenario):
    return f"""
You are a strict OSS compliance classifier.

Risk classification rules:

Low:
- MIT
- Apache-2.0
- BSD
- CC0
- Unlicense

Medium:
- LGPL
- MPL
- EPL
- CDDL
- weak copyleft licenses

High:
- GPL
- AGPL
- Proprietary
- Unknown
- Custom licenses
- strong copyleft licenses

Important:
LGPL is usually Medium risk, not High.

Scenario:
{scenario}

Return exactly:
Risk: <Low|Medium|High>
Reason: <one short sentence>
""".strip()

# %%
def predict_risk(scenario):
    prompt = build_prompt(scenario)

    messages = [
        {"role": "user", "content": prompt}
    ]

    text = tokenizer.apply_chat_template(
        messages,
        tokenize=False,
        add_generation_prompt=True
    )

    inputs = tokenizer([text], return_tensors="pt").to(model.device)

    outputs = model.generate(
        **inputs,
        max_new_tokens=120,
        do_sample=False
    )

    response = tokenizer.decode(
        outputs[0][inputs["input_ids"].shape[-1]:],
        skip_special_tokens=True
    )

    return response.strip()

# %%
def extract_risk(response):
    for line in response.split("\n"):
        line = line.strip().lower()

        if line.startswith("risk:"):
            value = line.replace("risk:", "").strip()

            if value.startswith("high"):
                return "High"
            elif value.startswith("medium"):
                return "Medium"
            elif value.startswith("low"):
                return "Low"

    return "Unknown"

# %%
responses = []
predicted_risks = []

for idx, row in df.iterrows():
    print(f"Processing {idx + 1}/{len(df)}")

    response = predict_risk(row["input"])

    predicted_risk = extract_risk(response)

    responses.append(response)
    predicted_risks.append(predicted_risk)

df["finetuned_response"] = responses
df["predicted_risk"] = predicted_risks

df.head()
# Out:
# Processing 1/20
# Processing 2/20
# Processing 3/20
# Processing 4/20
# Processing 5/20
# Processing 6/20
# Processing 7/20
# Processing 8/20
# Processing 9/20
# Processing 10/20
# Processing 11/20
# Processing 12/20
# Processing 13/20
# Processing 14/20
# Processing 15/20
# Processing 16/20
# Processing 17/20
# Processing 18/20
# Processing 19/20
# Processing 20/20
#                                                input expected_risk  \
# 0  License: MIT License Family: Permissive Projec...           Low
# 1  License: MIT License Family: Permissive Projec...           Low
# 2  License: Apache-2.0 License Family: Permissive...           Low
# 3  License: BSD-3-Clause License Family: Permissi...           Low
# 4  License: LGPL-2.1 License Family: Weak Copylef...        Medium
#
#                                   finetuned_response predicted_risk
# 0  Risk: Low\nReason: MIT License is typically us...            Low
# 1  Risk: Low\nReason: MIT License is typically us...            Low
# 2  Risk: Low\nReason: Apache-2.0 is a permissive ...            Low
# 3  Risk: Low\nReason: BSD license family is typic...            Low
# 4  Risk: Low\nReason: LGPL is typically considere...            Low

# %%
y_true = df["expected_risk"]
y_pred = df["predicted_risk"]

accuracy = accuracy_score(y_true, y_pred)

report = classification_report(
    y_true,
    y_pred,
    zero_division=0
)

cm = confusion_matrix(y_true, y_pred)

print("Fine-Tuned Qwen Accuracy:", accuracy)

print("\nClassification Report:")
print(report)

print("\nConfusion Matrix:")
print(cm)
# Out:
# Fine-Tuned Qwen Accuracy: 0.7
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         High       0.78      1.00      0.88         7
#          Low       0.64      1.00      0.78         7
#       Medium       0.00      0.00      0.00         6
#
#     accuracy                           0.70        20
#    macro avg       0.47      0.67      0.55        20
# weighted avg       0.49      0.70      0.58        20
#
#
# Confusion Matrix:
# [[7 0 0]
#  [0 7 0]
#  [2 4 0]]

# %%
comparison_df = pd.DataFrame({
    "Model": [
        "Base Qwen",
        "Fine-Tuned Qwen"
    ],
    "Accuracy": [
        1.0,   # replace if Step 4 changes
        accuracy
    ]
})

comparison_df
# Out:
#              Model  Accuracy
# 0        Base Qwen       1.0
# 1  Fine-Tuned Qwen       0.7
